# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
file = open(r'dataset\Uncleaned_employees_final_dataset (1).csv')
employees = pd.read_csv(r'dataset\Uncleaned_employees_final_dataset (1).csv', encoding=file.encoding)
file.close()

# %%
employees
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# ...

# %%
employees.ndim
# Out:
# 2

# %%
employees.shape
# Out:
# (17417, 13)

# %%
print(f'no. of employees: {employees.shape[0]}')
print(f'details per employee: {employees.shape[1]}')
# Out:
# no. of employees: 17417
# details per employee: 13

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17417 entries, 0 to 17416
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            17417 non-null  int64
#  1   department             17417 non-null  object
#  2   region                 17417 non-null  object
#  3   education              16646 non-null  object
#  4   gender                 17417 non-null  object
#  5   recruitment_channel    17417 non-null  object
#  6   no_of_trainings        17417 non-null  int64
#  7   age                    17417 non-null  int64
#  8   previous_year_rating   16054 non-null  float64
#  9   length_of_service      17417 non-null  int64
#  10  KPIs_met_more_than_80  17417 non-null  int64
#  11  awards_won             17417 non-null  int64
#  12  avg_training_score     17417 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.7+ MB

# %%
employees.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  17417.000000     17417.000000  17417.000000          16054.000000
# mean   39083.491129         1.250732     34.807774              3.345459
# std    22707.024087         0.595692      7.694046              1.265386
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19281.000000         1.000000     29.000000              3.000000
# 50%    39122.000000         1.000000     33.000000              3.000000
# 75%    58838.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met_more_than_80    awards_won  \
# count       17417.000000           17417.000000  17417.000000
# mean            5.801860               0.358845      0.023368
# std             4.175533               0.479675      0.151074
# ...

# %%
employees.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met_more_than_80', 'awards_won',
#        'avg_training_score'],
#       dtype='object')

# %%
employees_per_department = employees['department'].value_counts().to_frame()
employees_per_department
# Out:
#                    count
# department
# Sales & Marketing   5458
# Operations          3524
# Procurement         2240
# Technology          2199
# Analytics           1697
# HR                   833
# Finance              802
# Legal                332
# R&D                  332

# %%
fig, ax = plt.subplots()
ax.pie(employees_per_department['count'].tolist(), labels=employees_per_department.index.tolist(), autopct='%.1f%%')
plt.show()

# %%
employees_per_region = employees['region'].value_counts().to_frame()
employees_per_region = pd.DataFrame({'region':employees_per_region.index.tolist(), 'count':employees_per_region['count'].tolist()})
employees_per_region
# Out:
#        region  count
# 0    region_2   3918
# 1   region_22   1990
# 2    region_7   1488
# 3   region_13    860
# 4   region_15    843
# 5   region_26    748
# 6   region_31    646
# 7    region_4    571
# 8   region_27    516
# 9   region_16    452
# 10  region_28    430
# 11  region_11    420
# 12  region_23    376
# 13  region_32    318
# 14  region_19    315
# 15  region_29    308
# 16  region_17    268
# 17  region_14    265
# 18   region_5    252
# 19  region_25    248
# 20  region_20    242
# 21   region_6    220
# 22  region_30    209
# 23  region_10    209
# 24   region_8    209
# 25   region_1    174
# 26  region_24    165
# 27  region_12    156
# 28   region_9    134
# 29  region_21    129
# 30  region_34    123
# 31   region_3    110
# 32  region_33     91
# 33  region_18     14

# %%
print(employees_per_region.index.tolist())
# Out:
# ['region_2', 'region_22', 'region_7', 'region_13', 'region_15', 'region_26', 'region_31', 'region_4', 'region_27', 'region_16', 'region_28', 'region_11', 'region_23', 'region_32', 'region_19', 'region_29', 'region_17', 'region_14', 'region_5', 'region_25', 'region_20', 'region_6', 'region_30', 'region_10', 'region_8', 'region_1', 'region_24', 'region_12', 'region_9', 'region_21', 'region_34', 'region_3', 'region_33', 'region_18']

# %%
custom_dict = {'region_2':2, 'region_22':22, 'region_7':7, 'region_13':13, 'region_15':15, 'region_26':26,
               'region_31':31, 'region_4':4, 'region_27':27, 'region_16':16, 'region_28':28, 'region_11':11,
               'region_23':23, 'region_32':32, 'region_19':19, 'region_29':29, 'region_17':17,'region_14':14,
               'region_5':5, 'region_25':25, 'region_20':20, 'region_6':6, 'region_30':30, 'region_10':10,
               'region_8':8, 'region_1':1, 'region_24':24, 'region_12':12, 'region_9':9, 'region_21':21,
               'region_34':34, 'region_3':3, 'region_33':33, 'region_18':18}

# %%
employees_per_region = employees_per_region.sort_values(by=['region'], key=lambda x: x.map(custom_dict)).reset_index(drop=True)

# %%
employees_per_region.index
# Out:
# RangeIndex(start=0, stop=34, step=1)

# %%
plt.figure(figsize=(18,6))
plt.bar(employees_per_region['region'], employees_per_region['count'], width=.5)
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
employees.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 employees.corr(method='pearson')
#
# File d:\Rishik\projects\Employee Performance Analytics\venv\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File d:\Rishik\projects\Employee Performance Analytics\venv\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
# department pie chart
# region pie chart
# gender bar graph
# age vs prev year rating violin chart
# no. of training vs prev year rating

# %% [markdown]
# ____

# %% [markdown]
# Decision Tree

# %%
employees.dropna(inplace=True)

# %%
employees.iloc[:,]
# Out:
#        employee_id         department     region  education gender  \
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# 5            46232        Procurement   region_7  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 1                   other                1   31                   3.0
# ...

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder

# %%
1:11

# %%
x_train, x_test, y_train, y_test = train_test_split(employees.iloc[:,1:12], employees.iloc[:,[12]], train_size=.8)

# %%
regressor = DecisionTreeRegressor(max_depth=7)

# %%
label_encoder = LabelEncoder()

# %%
employees['region']
# Out:
# 1         region_4
# 2        region_13
# 3         region_2
# 4        region_29
# 5         region_7
#            ...
# 17412     region_7
# 17413     region_7
# 17414     region_7
# 17415     region_7
# 17416     region_7
# Name: region, Length: 15424, dtype: object

# %%
employees.iloc[:,5] = label_encoder.fit_transform(employees.iloc[:,5])

# %%
employees
# Out:
#        employee_id  department  region education gender recruitment_channel  \
# 1            74430           2      28         0      0                   0
# 2            72255           7       4         0      1                   0
# 3            38562           5      11         0      0                   0
# 4            64486           1      21         0      1                   2
# 5            46232           5      31         0      1                   2
# ...            ...         ...     ...       ...    ...                 ...
# 17412        64573           8      31         0      0                   1
# 17413        49584           2      31         0      1                   0
# 17414        49584           2      31         0      1                   0
# 17415        49584           2      31         0      1                   0
# 17416        64573           2      31         0      0                   1
#
# ...

# %%
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=7)
